# %% [markdown]
# # 0. Imports

# %%
import pandas as pd
from scrapper import elo_rating

# %% [markdown]
# # 1. Read Multiple Dates

# %% [markdown]
# The scrapper works on yearly ratings. It is possible to choose the year of interest. I decided for the year before World Cup.

# %%
df_rating_year_before_cup = elo_rating.get_elo_rating(dates=[1993, 1997, 2001, 2005, 2009, 2013, 2017, 2021])

# %%
df_rating_year_before_cup
# Out:
#        RK               Team Rating AverageRank AverageRating YearRank  \
# Year
# 1993    1            Germany   2015           9          1883       +2
# 1993    2              Italy   2000           8          1901       +2
# 1993    3        Netherlands   1995          18          1798       +2
# 1993    4             Brazil   1950           5          1975       −2
# 1993    5         Yugoslavia   1933          19          1775       +2
# ...   ...                ...    ...         ...           ...      ...
# 2021  235              Tonga    528         210           665        0
# 2021  236               Niue    496         222           496        0
# 2021  237      Eastern Samoa    472         222           473        0
# 2021  238  Northern Marianas    409         229           528        0
# 2021  239              Palau    403         233           403        0
#
#      YearRating MatchesTotal MathcesHome MatchesAway MatchesNeutral  \
# Year
# 1993        +21          612         269         261             82
# 1993        +20          507         246         192             69
# 1993        +27          512         246         219             47
# 1993        −49          590         244         192            154
# 1993          0          523         192         253             78
# ...         ...          ...         ...         ...            ...
# 2021          0           62           8          14             40
# 2021          0            2           0           0              2
# 2021          0           51           0          13             38
# 2021          0           26           3           9             14
# 2021          0            2           2           0              0
#
#      MatchesWins MatchesLosses MatchesDraws GoalsFor GoalsAgainst
# Year
# 1993         343           145          124     1378          786
# 1993         270           107          130      942          557
# 1993         238           170          104     1075          802
# 1993         359           108          123     1270          608
# 1993         252           169          102     1097          816
# ...          ...           ...          ...      ...          ...
# 2021          14            42            6       70          242
# 2021           0             2            0        0           33
# 2021           4            45            2       30          340
# 2021           3            21            2       31          116
# 2021           0             2            0        3           27
#
# [1848 rows x 16 columns]

# %% [markdown]
# # 2. Saving into CSV

# %%
df_rating_year_before_cup.to_csv('./datasets/elo_rating.csv')
